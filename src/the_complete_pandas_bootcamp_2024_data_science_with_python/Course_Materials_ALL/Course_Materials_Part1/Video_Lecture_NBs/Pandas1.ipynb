# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
print(titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.min_rows
# Out:
# 10

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.describe(include='O')
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic.max(numeric_only=True)
# Out:
# survived      1.0000
# pclass        3.0000
# age          80.0000
# sibsp         8.0000
# parch         6.0000
# fare        512.3292
# dtype: float64

# %%
titanic.min(numeric_only=True)
# Out:
# survived    0.00
# pclass      1.00
# age         0.42
# sibsp       0.00
# parch       0.00
# fare        0.00
# dtype: float64

# %%
titanic.mean(numeric_only=True).sort_values()
# Out:
# parch        0.381594
# survived     0.383838
# sibsp        0.523008
# pclass       2.308642
# age         29.699118
# fare        32.204208
# dtype: float64

# %%
titanic.mean(numeric_only=True).sort_values().head(2)
# Out:
# parch       0.381594
# survived    0.383838
# dtype: float64

# %%
titanic.sort_values(by=[ 'sex', 'age'], ascending=True)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 469         1       3  female  0.75      2      1  19.2583        C  NaN
# 644         1       3  female  0.75      2      1  19.2583        C  NaN
# 172         1       3  female  1.00      1      1  11.1333        S  NaN
# 381         1       3  female  1.00      0      2  15.7417        C  NaN
# 119         0       3  female  2.00      4      2  31.2750        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 839         1       1    male   NaN      0      0  29.7000        C    C
# 846         0       3    male   NaN      8      2  69.5500        S  NaN
# 859         0       3    male   NaN      0      0   7.2292        C  NaN
# 868         0       3    male   NaN      0      0   9.5000        S  NaN
# 878         0       3    male   NaN      0      0   7.8958        S  NaN
#
# [891 rows x 9 columns]

# %%
titanic['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
type(titanic['age'])
# Out:
# pandas.core.series.Series

# %%
titanic['age'][2]
# Out:
# np.float64(26.0)

# %%
titanic[['age', 'sex']]
# Out:
#       age     sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
type(titanic[['age', 'sex']])
# Out:
# pandas.core.frame.DataFrame

# %%
summer = pd.read_csv('summer.csv', index_col='Athlete')

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31165 entries, HAJOS, Alfred to LIDBERG, Jimmy
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Country     31161 non-null  object
#  5   Gender      31165 non-null  object
#  6   Event       31165 non-null  object
#  7   Medal       31165 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %%
summer
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
print(summer)
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender                       Event   Medal
# Athlete
# ...

# %%
summer.iloc[0]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: HAJOS, Alfred, dtype: object

# %%
print(summer.iloc[0])
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: HAJOS, Alfred, dtype: object

# %%
summer.iloc[:3]
# Out:
#                    Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred      1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto   1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                         Event   Medal
# Athlete
# HAJOS, Alfred                  100M Freestyle    Gold
# HERSCHMANN, Otto               100M Freestyle  Silver
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze

# %%
summer.iloc[1,5]
# Out:
# 'Men'

# %%
summer.iloc[23:27, [2,4,5]]
# Out:
#                         Sport Country Gender
# Athlete
# GOLEMIS, Dimitrios  Athletics     GRE    Men
# FLACK, Edwin        Athletics     AUS    Men
# DANI, Nandor        Athletics     HUN    Men
# VERSIS, Sotirios    Athletics     GRE    Men

# %%
summer.loc['GOLEMIS, Dimitrios']
# Out:
# Year               1896
# City             Athens
# Sport         Athletics
# Discipline    Athletics
# Country             GRE
# Gender              Men
# Event              800M
# Medal            Bronze
# Name: GOLEMIS, Dimitrios, dtype: object

# %%
summer.loc['PHELPS, Michael']
# Out:
#                  Year     City     Sport Discipline Country Gender  \
# Athlete
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# ...

# %%
summer.loc['PHELPS, Michael', 'Medal']
# Out:
# Athlete
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Bronze
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Bronze
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Silver
# PHELPS, Michael      Gold
# PHELPS, Michael    Silver
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# Name: Medal, dtype: object

# %%
summer.loc['PHELPS, Michael',['Medal', 'Event']]
# Out:
#                   Medal                   Event
# Athlete
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael  Bronze          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael  Bronze  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael    Gold          200M Butterfly
# PHELPS, Michael    Gold          200M Freestyle
# PHELPS, Michael    Gold  200M Individual Medley
# PHELPS, Michael    Gold  400M Individual Medley
# PHELPS, Michael    Gold  4X100M Freestyle Relay
# PHELPS, Michael    Gold     4X100M Medley Relay
# PHELPS, Michael    Gold  4X200M Freestyle Relay
# PHELPS, Michael    Gold          100M Butterfly
# PHELPS, Michael  Silver          200M Butterfly
# ...

# %%
summer.loc[['PHELPS, Michael','GOLEMIS, Dimitrios'],['Medal', 'Event']]
# Out:
#                      Medal                   Event
# Athlete
# PHELPS, Michael       Gold          100M Butterfly
# PHELPS, Michael       Gold          200M Butterfly
# PHELPS, Michael     Bronze          200M Freestyle
# PHELPS, Michael       Gold  200M Individual Medley
# PHELPS, Michael       Gold  400M Individual Medley
# PHELPS, Michael     Bronze  4X100M Freestyle Relay
# PHELPS, Michael       Gold     4X100M Medley Relay
# PHELPS, Michael       Gold  4X200M Freestyle Relay
# PHELPS, Michael       Gold          100M Butterfly
# PHELPS, Michael       Gold          200M Butterfly
# PHELPS, Michael       Gold          200M Freestyle
# PHELPS, Michael       Gold  200M Individual Medley
# PHELPS, Michael       Gold  400M Individual Medley
# PHELPS, Michael       Gold  4X100M Freestyle Relay
# PHELPS, Michael       Gold     4X100M Medley Relay
# PHELPS, Michael       Gold  4X200M Freestyle Relay
# PHELPS, Michael       Gold          100M Butterfly
# ...

# %%
print(summer.loc[['PHELPS, Michael','GOLEMIS, Dimitrios'],['Medal', 'Event']])
# Out:
#                      Medal                   Event
# Athlete
# PHELPS, Michael       Gold          100M Butterfly
# PHELPS, Michael       Gold          200M Butterfly
# PHELPS, Michael     Bronze          200M Freestyle
# PHELPS, Michael       Gold  200M Individual Medley
# PHELPS, Michael       Gold  400M Individual Medley
# PHELPS, Michael     Bronze  4X100M Freestyle Relay
# PHELPS, Michael       Gold     4X100M Medley Relay
# PHELPS, Michael       Gold  4X200M Freestyle Relay
# PHELPS, Michael       Gold          100M Butterfly
# PHELPS, Michael       Gold          200M Butterfly
# PHELPS, Michael       Gold          200M Freestyle
# PHELPS, Michael       Gold  200M Individual Medley
# PHELPS, Michael       Gold  400M Individual Medley
# PHELPS, Michael       Gold  4X100M Freestyle Relay
# PHELPS, Michael       Gold     4X100M Medley Relay
# PHELPS, Michael       Gold  4X200M Freestyle Relay
# PHELPS, Michael       Gold          100M Butterfly
# ...

# %%
summer.head(10)
# Out:
#                        Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto       1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens  Aquatics   Swimming     AUT    Men
#
#                                             Event   Medal
# Athlete
# HAJOS, Alfred                      100M Freestyle    Gold
# ...

# %%
summer.loc[:"CHASAPIS, Spiridon"]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
print(summer.head(20))
# Out:
#                        Year    City      Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred          1896  Athens   Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto       1896  Athens   Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens   Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens   Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens   Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens   Aquatics   Swimming     AUT    Men
# PEPANOS, Antonios      1896  Athens   Aquatics   Swimming     GRE    Men
# LANE, Francis          1896  Athens  Athletics  Athletics     USA    Men
# ...

# %%
summer.index
# Out:
# Index(['HAJOS, Alfred', 'HERSCHMANN, Otto', 'DRIVAS, Dimitrios',
#        'MALOKINIS, Ioannis', 'CHASAPIS, Spiridon', 'CHOROPHAS, Efstathios',
#        'HAJOS, Alfred', 'ANDREOU, Joannis', 'CHOROPHAS, Efstathios',
#        'NEUMANN, Paul',
#        ...
#        'AHMADOV, Emin', 'KAZAKEVIC, Aleksandr', 'KHUGAEV, Alan',
#        'EBRAHIM, Karam Mohamed Gaber', 'GAJIYEV, Danyal', 'JANIKOWSKI, Damian',
#        'REZAEI, Ghasem Gholamreza', 'TOTROV, Rustam', 'ALEKSANYAN, Artur',
#        'LIDBERG, Jimmy'],
#       dtype='object', name='Athlete', length=31165)

# %%
'Year' in summer.columns
# Out:
# True

# %%
summer.info
# Out:
# <bound method DataFrame.info of                            Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred              1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto           1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios          1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis         1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon         1896  Athens   Aquatics             Swimming
# ...                         ...     ...        ...                  ...
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
# ...

# %%
summer.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Country', 'Gender', 'Event',
#        'Medal'],
#       dtype='object')

# %%
summer.index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 summer.index = 'Year'
#
# File ~/Documents/the-complete-pandas-bootcamp-2024-data-science-with-python/.venv/lib/python3.12/site-packages/pandas/core/generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/Documents/the-complete-pandas-bootcamp-2024-data-science-with-python/.venv/lib/python3.12/site-packages/pandas/core/generic.py:813, in NDFrame._set_axis(self, axis, labels)
#     807 @final
#     808 def _set_axis(self, axis: AxisInt, labels: AnyArrayLike | list) -> None:
#     809     """
# ...

# %%
summer.loc["UNDA, Maider"]
# Out:
# Year                         2012
# City                       London
# Sport                   Wrestling
# Discipline    Wrestling Freestyle
# Country                       ESP
# Gender                      Women
# Event                    Wf 72 KG
# Medal                      Bronze
# Name: UNDA, Maider, dtype: object

# %%
summer.loc["UNDA, Maider"]['Event']
# Out:
# 'Wf 72 KG'

# %%
summer.loc["UNDA, Maider", 'Event']
# Out:
# 'Wf 72 KG'

# %%
summer.loc[["PAVIA, Automne", "OCHAL, Glenn"], ["Country", "Sport"]]
# Out:
#                Country   Sport
# Athlete
# PAVIA, Automne     FRA    Judo
# OCHAL, Glenn       USA  Rowing
